# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,models, optimizers, callbacks
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#generating data

train_ds=keras.utils.image_dataset_from_directory(
    directory='DIAT-uSAT_dataset_new/train',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(224, 224),
    shuffle=True
)

val_ds=keras.utils.image_dataset_from_directory(
    directory='DIAT-uSAT_dataset_new/val',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(224,224),
    shuffle=False
)
test_ds=keras.utils.image_dataset_from_directory(
    directory='DIAT-uSAT_dataset_new/test',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(224,224),
    shuffle=False
)
# Out:
# Found 4120 files belonging to 6 classes.
# Found 240 files belonging to 6 classes.
# Found 489 files belonging to 6 classes.

# %%
#creating custom model

# Sequential model
model = models.Sequential()

# 1st Convolutional Block
model.add(layers.Conv2D(16, (3, 3), padding='same', activation='relu' ,input_shape=(224, 224, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# 2nd Convolutional Block
model.add(layers.Conv2D(32, (3, 3), padding='same',activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# 3rd Convolutional Block
model.add(layers.Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# 4th Convolutional Block
model.add(layers.Conv2D(128, (3, 3), padding='same',activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# Global Average Pooling
model.add(layers.GlobalAveragePooling2D())

# Fully Connected Layers
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(6, activation='softmax'))  # Output for 6 classes
# Out:
# c:\Users\amrit\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

lr_scheduler = callbacks.ReduceLROnPlateau(
    monitor='val_loss',  
    factor=0.5,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 167,526 (654.40 KB)
#  Trainable params: 167,046 (652.52 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 51s 376ms/step - accuracy: 0.4888 - loss: 1.3787 - val_accuracy: 0.2167 - val_loss: 1.7198 - learning_rate: 1.0000e-04
# Epoch 2/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 359ms/step - accuracy: 0.7797 - loss: 0.6148 - val_accuracy: 0.3625 - val_loss: 1.1982 - learning_rate: 1.0000e-04
# Epoch 3/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 352ms/step - accuracy: 0.8352 - loss: 0.4396 - val_accuracy: 0.8250 - val_loss: 0.5176 - learning_rate: 1.0000e-04
# Epoch 4/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 358ms/step - accuracy: 0.8952 - loss: 0.3241 - val_accuracy: 0.9167 - val_loss: 0.2779 - learning_rate: 1.0000e-04
# Epoch 5/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 356ms/step - accuracy: 0.9230 - loss: 0.2542 - val_accuracy: 0.9125 - val_loss: 0.2552 - learning_rate: 1.0000e-04
# Epoch 6/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 47s 363ms/step - accuracy: 0.9371 - loss: 0.2127 - val_accuracy: 0.9167 - val_loss: 0.2346 - learning_rate: 1.0000e-04
# Epoch 7/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 45s 351ms/step - accuracy: 0.9501 - loss: 0.1707 - val_accuracy: 0.9000 - val_loss: 0.2568 - learning_rate: 1.0000e-04
# Epoch 8/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 47s 361ms/step - accuracy: 0.9485 - loss: 0.1556 - val_accuracy: 0.9417 - val_loss: 0.1894 - learning_rate: 1.0000e-04
# Epoch 9/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 354ms/step - accuracy: 0.9630 - loss: 0.1248 - val_accuracy: 0.9667 - val_loss: 0.1365 - learning_rate: 1.0000e-04
# Epoch 10/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 47s 362ms/step - accuracy: 0.9693 - loss: 0.1118 - val_accuracy: 0.9250 - val_loss: 0.2353 - learning_rate: 1.0000e-04
# Epoch 11/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9761 - loss: 0.0986
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 45s 350ms/step - accuracy: 0.9761 - loss: 0.0986 - val_accuracy: 0.9292 - val_loss: 0.2070 - learning_rate: 1.0000e-04
# Epoch 12/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 353ms/step - accuracy: 0.9687 - loss: 0.0926 - val_accuracy: 0.9708 - val_loss: 0.0944 - learning_rate: 5.0000e-05
# Epoch 13/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 47s 361ms/step - accuracy: 0.9782 - loss: 0.0791 - val_accuracy: 0.9667 - val_loss: 0.0847 - learning_rate: 5.0000e-05
# Epoch 14/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 360ms/step - accuracy: 0.9842 - loss: 0.0649 - val_accuracy: 0.9667 - val_loss: 0.0821 - learning_rate: 5.0000e-05
# Epoch 15/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 49s 382ms/step - accuracy: 0.9829 - loss: 0.0681 - val_accuracy: 0.9583 - val_loss: 0.1085 - learning_rate: 5.0000e-05
# Epoch 16/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9826 - loss: 0.0608
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 48s 373ms/step - accuracy: 0.9826 - loss: 0.0609 - val_accuracy: 0.9667 - val_loss: 0.1024 - learning_rate: 5.0000e-05
# Epoch 17/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 352ms/step - accuracy: 0.9821 - loss: 0.0549 - val_accuracy: 0.9625 - val_loss: 0.0844 - learning_rate: 2.5000e-05
# Epoch 18/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 354ms/step - accuracy: 0.9855 - loss: 0.0583 - val_accuracy: 0.9750 - val_loss: 0.0674 - learning_rate: 2.5000e-05
# Epoch 19/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 359ms/step - accuracy: 0.9870 - loss: 0.0479 - val_accuracy: 0.9667 - val_loss: 0.0701 - learning_rate: 2.5000e-05
# Epoch 20/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9877 - loss: 0.0501
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 48s 371ms/step - accuracy: 0.9877 - loss: 0.0501 - val_accuracy: 0.9625 - val_loss: 0.0750 - learning_rate: 2.5000e-05

# %%
test_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 6), dtype=tf.float32, name=None))>

# %%
# If test_data is a tf.data.Dataset object
loss, accuracy = model.evaluate(test_ds)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9711 - loss: 0.0994

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(history.history['loss'],label='train')
#       2 plt.plot(history.history['val_loss'],label='validation')
#       3 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
import cv2
test_img=cv2.imread("DIAT-uSAT_dataset_new/train/Bird/figure68.jpg")

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (525, 700, 3)

# %%
test_img=cv2.resize(test_img,(224,224))

# %%
test_input=test_img.reshape((1,224,224,3))

# %%
predictions = model.predict(test_input)[0]

#defining a dictionary for labels

d={0:'3 long blade rotor',
   1: '3 short blade rotor',
   2:'bird',
   3:'bird with mini helicopter',
   4:'drone',
   5:'rc plane'}

#Get the index of the maximum element
max_index = np.argmax(predictions)
# Get the maximum value
max_value = predictions[max_index]
print(f"Probability: {max_value}, Class: {d[max_index]}")

predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Probability: 0.9705657958984375, Class: 3 short blade rotor
# array([3.7582940e-03, 9.7056580e-01, 2.1835450e-02, 7.8821704e-06,
#        3.4908573e-03, 3.4176849e-04], dtype=float32)
